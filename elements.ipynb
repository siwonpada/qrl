# %% [markdown]
# 각 library에서 제공하는 함수 혹은 class들의 역할을 뜯어보고 어떻게 쓰일 수 있는지 테스트를 해본 파일입니다.

# %% [markdown]
# # Gymnasium
# openai에서 만든 RL platform이다.

# %%
import gymnasium as gym
import random
from PIL import Image

env = gym.make('CartPole-v1', render_mode='rgb_array')

state, info = env.reset()
screen = env.render()
image = Image.fromarray(screen)

display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
action = random.randint(0, 1)
observation, reward, terminated, truncated, info = env.step(action=action)
screen = env.render()
image = Image.fromarray(screen)
print(action)
print('observation:', observation)
print('reward:', reward)
print('terminated:', terminated)
print('truncated:', truncated) 
display(image)
# Out:
# 1
# observation: [  3.089035    2.6386018 -10.325698   -9.332913 ]
# reward: 0.0
# terminated: True
# truncated: False
# <PIL.Image.Image image mode=RGB size=600x400>

# %% [markdown]
# # Pytorch
# deep learning을 위한 라이브러리이다.
